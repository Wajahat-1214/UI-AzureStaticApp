# %%
import json

#read json file named as "resources.json"
with open('./Data/resource.json') as f:
    resources = json.load(f)
    f.close()

resources, len(resources)
# Out:
# ([{'id': '1001',
#    'name': 'Resource 1',
#    'role': 'Developer',
#    'build_allocation': 'true',
#    'rate': 50,
#    'phases': [{'name': 'Initialization',
#      'hours_allocation': 0,
#      'weeks_allocation': 0,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Solution Modelling',
#      'hours_allocation': 0.5,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Build',
#      'hours_allocation': 1,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Solution Testing',
#      'hours_allocation': 1,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Deployment',
#      'hours_allocation': 0,
#      'weeks_allocation': 0,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Support',
#      'hours_allocation': 0,
#      'weeks_allocation': 0,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0}]},
#   {'id': '1002',
#    'name': 'Resource 2',
#    'role': 'Developer',
#    'build_allocation': 'true',
#    'rate': 60,
#    'phases': [{'name': 'Initialization',
#      'hours_allocation': 0,
#      'weeks_allocation': 0,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Solution Modelling',
#      'hours_allocation': 0.5,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Build',
#      'hours_allocation': 1,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Solution Testing',
#      'hours_allocation': 1,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Deployment',
#      'hours_allocation': 0,
#      'weeks_allocation': 0,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Support',
#      'hours_allocation': 0,
#      'weeks_allocation': 0,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0}]},
#   {'id': '1003',
#    'name': 'Resource 3',
#    'role': 'Developer',
#    'build_allocation': 'true',
#    'rate': 45,
#    'phases': [{'name': 'Initialization',
#      'hours_allocation': 0,
#      'weeks_allocation': 0,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Solution Modelling',
#      'hours_allocation': 0.5,
#      'weeks_allocation': 0.5,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Build',
#      'hours_allocation': 1,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Solution Testing',
#      'hours_allocation': 1,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Deployment',
#      'hours_allocation': 0,
#      'weeks_allocation': 0,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Support',
#      'hours_allocation': 0,
#      'weeks_allocation': 0,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0}]},
#   {'id': '1004',
#    'name': 'Resource 4',
#    'role': 'Solution Architect',
#    'build_allocation': 'true',
#    'rate': 100,
#    'phases': [{'name': 'Initialization',
#      'hours_allocation': 1,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Solution Modelling',
#      'hours_allocation': 1,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Build',
#      'hours_allocation': 0.5,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Solution Testing',
#      'hours_allocation': 0.5,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Deployment',
#      'hours_allocation': 0.5,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Support',
#      'hours_allocation': 1,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0}]},
#   {'id': '1005',
#    'name': 'Resource 5',
#    'role': 'Project Manager',
#    'build_allocation': 'true',
#    'rate': 100,
#    'phases': [{'name': 'Initialization',
#      'hours_allocation': 0.25,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Solution Modelling',
#      'hours_allocation': 0.25,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Build',
#      'hours_allocation': 0.25,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Solution Testing',
#      'hours_allocation': 0.25,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Deployment',
#      'hours_allocation': 0.25,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Support',
#      'hours_allocation': 0.25,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0}]}],
#  5)

# %%
from DatabaseCosmos.resource_state import getResources, initialize_resource, updateResources
id = "20250107234801-c44fe4251105"

get_resources = getResources(id)
if not get_resources:
    initialize_resource(id)
    resources = getResources(id)
# Out:
# Reading Resources
# Retrieved item: {'user_id': '112233', 'id': '20250107234801-c44fe4251105', 'resources': [{'id': '1001', 'name': 'Resource 1', 'role': 'Developer', 'build_allocation': 'true', 'rate': 50, 'phases': [{'name': 'Initialization', 'hours_allocation': 0, 'weeks_allocation': 0, 'order': 1, 'total_hours': 0, 'total_cost': 0, 'total_weeks': 0}, {'name': 'Solution Modelling', 'hours_allocation': 0.5, 'weeks_allocation': 1, 'order': 1, 'total_hours': 0, 'total_cost': 0, 'total_weeks': 0}, {'name': 'Build', 'hours_allocation': 1, 'weeks_allocation': 1, 'order': 1, 'total_hours': 0, 'total_cost': 0, 'total_weeks': 0}, {'name': 'Solution Testing', 'hours_allocation': 1, 'weeks_allocation': 1, 'order': 1, 'total_hours': 0, 'total_cost': 0, 'total_weeks': 0}, {'name': 'Deployment', 'hours_allocation': 0, 'weeks_allocation': 0, 'order': 1, 'total_hours': 0, 'total_cost': 0, 'total_weeks': 0}, {'name': 'Support', 'hours_allocation': 0, 'weeks_allocation': 0, 'order': 1, 'total_hours': 0, 'total_cost': 0, 'total_weeks': 0}]}, {'id': '1002', 'name': 'Resource 2', 'role': 'Developer', 'build_allocation': 'true', 'rate': 60, 'phases': [{'name': 'Initialization', 'hours_allocation': 0, 'weeks_allocation': 0, 'order': 1, 'total_hours': 0, 'total_cost': 0, 'total_weeks': 0}, {'name': 'Solution Modelling', 'hours_allocation': 0.5, 'weeks_allocation': 1, 'order': 1, 'total_hours': 0, 'total_cost': 0, 'total_weeks': 0}, {'name': 'Build', 'hours_allocation': 1, 'weeks_allocation': 1, 'order': 1, 'total_hours': 0, 'total_cost': 0, 'total_weeks': 0}, {'name': 'Solution Testing', 'hours_allocation': 1, 'weeks_allocation': 1, 'order': 1, 'total_hours': 0, 'total_cost': 0, 'total_weeks': 0}, {'name': 'Deployment', 'hours_allocation': 0, 'weeks_allocation': 0, 'order': 1, 'total_hours': 0, 'total_cost': 0, 'total_weeks': 0}, {'name': 'Support', 'hours_allocation': 0, 'weeks_allocation': 0, 'order': 1, 'total_hours': 0, 'total_cost': 0, 'total_weeks': 0}]}, {'id': '1003', 'name': 'Resource 3', 'role': 'Developer', 'build_allocation': 'true', 'rate': 45, 'phases': [{'name': 'Initialization', 'hours_allocation': 0, 'weeks_allocation': 0, 'order': 1, 'total_hours': 0, 'total_cost': 0, 'total_weeks': 0}, {'name': 'Solution Modelling', 'hours_allocation': 0.5, 'weeks_allocation': 0.5, 'order': 1, 'total_hours': 0, 'total_cost': 0, 'total_weeks': 0}, {'name': 'Build', 'hours_allocation': 1, 'weeks_allocation': 1, 'order': 1, 'total_hours': 0, 'total_cost': 0, 'total_weeks': 0}, {'name': 'Solution Testing', 'hours_allocation': 1, 'weeks_allocation': 1, 'order': 1, 'total_hours': 0, 'total_cost': 0, 'total_weeks': 0}, {'name': 'Deployment', 'hours_allocation': 0, 'weeks_allocation': 0, 'order': 1, 'total_hours': 0, 'total_cost': 0, 'total_weeks': 0}, {'name': 'Support', 'hours_allocation': 0, 'weeks_allocation': 0, 'order': 1, 'total_hours': 0, 'total_cost': 0, 'total_weeks': 0}]}, {'id': '1004', 'name': 'Resource 4', 'role': 'Solution Architect', 'build_allocation': 'true', 'rate': 100, 'phases': [{'name': 'Initialization', 'hours_allocation': 1, 'weeks_allocation': 1, 'order': 1, 'total_hours': 0, 'total_cost': 0, 'total_weeks': 0}, {'name': 'Solution Modelling', 'hours_allocation': 1, 'weeks_allocation': 1, 'order': 1, 'total_hours': 0, 'total_cost': 0, 'total_weeks': 0}, {'name': 'Build', 'hours_allocation': 0.5, 'weeks_allocation': 1, 'order': 1, 'total_hours': 0, 'total_cost': 0, 'total_weeks': 0}, {'name': 'Solution Testing', 'hours_allocation': 0.5, 'weeks_allocation': 1, 'order': 1, 'total_hours': 0, 'total_cost': 0, 'total_weeks': 0}, {'name': 'Deployment', 'hours_allocation': 0.5, 'weeks_allocation': 1, 'order': 1, 'total_hours': 0, 'total_cost': 0, 'total_weeks': 0}, {'name': 'Support', 'hours_allocation': 1, 'weeks_allocation': 1, 'order': 1, 'total_hours': 0, 'total_cost': 0, 'total_weeks': 0}]}, {'id': '1005', 'name': 'Resource 5', 'role': 'Project Manager', 'build_allocation': 'true', 'rate': 100, 'phases': [{'name': 'Initialization', 'hours_allocation':  ...

# %%
user_id = "112233"

# %%
initialize_resource(user_id, id)
# Out:
# Initializing Resources
# Reading Resources
# Retrieved item: {'user_id': '112233', 'id': '20241217133444-4823bc8ebb4d', 'resources': [12345, 12345, 12345], '_rid': 'lOx3AK7jmokBAAAAAAAAAA==', '_self': 'dbs/lOx3AA==/colls/lOx3AK7jmok=/docs/lOx3AK7jmokBAAAAAAAAAA==/', '_etag': '"d60060d8-0000-0100-0000-67ab71d90000"', '_attachments': 'attachments/', '_ts': 1739289049}
# Item already exists
# {'user_id': '112233',
#  'id': '20241217133444-4823bc8ebb4d',
#  'resources': [12345, 12345, 12345],
#  '_rid': 'lOx3AK7jmokBAAAAAAAAAA==',
#  '_self': 'dbs/lOx3AA==/colls/lOx3AK7jmok=/docs/lOx3AK7jmokBAAAAAAAAAA==/',
#  '_etag': '"d60060d8-0000-0100-0000-67ab71d90000"',
#  '_attachments': 'attachments/',
#  '_ts': 1739289049}

# %%
updateResources(id, data)
# Out:
# Updating Resources Section
# Reading Resources
# Retrieved item: {'user_id': '112233', 'id': '20241217133444-4823bc8ebb4d', 'resources': [12345], '_rid': 'lOx3AK7jmokBAAAAAAAAAA==', '_self': 'dbs/lOx3AA==/colls/lOx3AK7jmok=/docs/lOx3AK7jmokBAAAAAAAAAA==/', '_etag': '"d60067d8-0000-0100-0000-67ab71ef0000"', '_attachments': 'attachments/', '_ts': 1739289071}
# Upserted Item's Id is 20241217133444-4823bc8ebb4d
# {'user_id': '112233',
#  'id': '20241217133444-4823bc8ebb4d',
#  'resources': [{'id': '1001',
#    'name': 'Resource 1',
#    'role': 'Developer',
#    'build_allocation': 'true',
#    'rate': 50,
#    'phases': [{'name': 'Initialization',
#      'hours_allocation': 0,
#      'weeks_allocation': 0,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Solution Modelling',
#      'hours_allocation': 0.5,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Build',
#      'hours_allocation': 1,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Solution Testing',
#      'hours_allocation': 1,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Deployment',
#      'hours_allocation': 0,
#      'weeks_allocation': 0,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Support',
#      'hours_allocation': 0,
#      'weeks_allocation': 0,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0}]},
#   {'id': '1002',
#    'name': 'Resource 2',
#    'role': 'Developer',
#    'build_allocation': 'true',
#    'rate': 60,
#    'phases': [{'name': 'Initialization',
#      'hours_allocation': 0,
#      'weeks_allocation': 0,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Solution Modelling',
#      'hours_allocation': 0.5,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Build',
#      'hours_allocation': 1,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Solution Testing',
#      'hours_allocation': 1,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Deployment',
#      'hours_allocation': 0,
#      'weeks_allocation': 0,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Support',
#      'hours_allocation': 0,
#      'weeks_allocation': 0,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0}]},
#   {'id': '1003',
#    'name': 'Resource 3',
#    'role': 'Developer',
#    'build_allocation': 'true',
#    'rate': 45,
#    'phases': [{'name': 'Initialization',
#      'hours_allocation': 0,
#      'weeks_allocation': 0,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Solution Modelling',
#      'hours_allocation': 0.5,
#      'weeks_allocation': 0.5,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Build',
#      'hours_allocation': 1,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Solution Testing',
#      'hours_allocation': 1,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Deployment',
#      'hours_allocation': 0,
#      'weeks_allocation': 0,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Support',
#      'hours_allocation': 0,
#      'weeks_allocation': 0,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0}]},
#   {'id': '1004',
#    'name': 'Resource 4',
#    'role': 'Solution Architect',
#    'build_allocation': 'true',
#    'rate': 100,
#    'phases': [{'name': 'Initialization',
#      'hours_allocation': 1,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Solution Modelling',
#      'hours_allocation': 1,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Build',
#      'hours_allocation': 0.5,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Solution Testing',
#      'hours_allocation': 0.5,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Deployment',
#      'hours_allocation': 0.5,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Support',
#      'hours_allocation': 1,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0}]},
#   {'id': '1005',
#    'name': 'Resource 5',
#    'role': 'Project Manager',
#    'build_allocation': 'true',
#    'rate': 100,
#    'phases': [{'name': 'Initialization',
#      'hours_allocation': 0.25,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Solution Modelling',
#      'hours_allocation': 0.25,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Build',
#      'hours_allocation': 0.25,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Solution Testing',
#      'hours_allocation': 0.25,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Deployment',
#      'hours_allocation': 0.25,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0},
#     {'name': 'Support',
#      'hours_allocation': 0.25,
#      'weeks_allocation': 1,
#      'order': 1,
#      'total_hours': 0,
#      'total_cost': 0,
#      'total_weeks': 0}]}],
#  '_rid': 'lOx3AK7jmokBAAAAAAAAAA==',
#  '_self': 'dbs/lOx3AA==/colls/lOx3AK7jmok=/docs/lOx3AK7jmokBAAAAAAAAAA==/',
#  '_etag': '"d60031e6-0000-0100-0000-67ab75a00000"',
#  '_attachments': 'attachments/',
#  '_ts': 1739290016}
